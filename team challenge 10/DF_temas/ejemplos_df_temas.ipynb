# %%
import pandas as pd

# %%
https://www.kaggle.com/datasets/willianoliveiragibin/casino-gaming-data

# %%
df=pd.read_csv("./Casino_Gaming_Data_new.csv")
df
# Out:
#     Fiscal Year            Month Ending                             Licensee  \
# 0       2021/22  06/30/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# 1       2021/22  06/30/2022 12:00:00 AM                  MPTN On-Reservation
# 2       2021/22  06/30/2022 12:00:00 AM  MPI Master Wagering License CT, LLC
# 3       2021/22  06/30/2022 12:00:00 AM                 Mohegan Digital, LLC
# 4       2021/22  05/31/2022 12:00:00 AM         Mohegan Tribe On-Reservation
# ..          ...                     ...                                  ...
# 138     2024/25  08/31/2024 12:00:00 AM                 Mohegan Digital, LLC
# 139     2024/25  07/31/2024 12:00:00 AM         Mohegan Tribe On-Reservation
# 140     2024/25  07/31/2024 12:00:00 AM                  MPTN On-Reservation
# 141     2024/25  07/31/2024 12:00:00 AM  MPI Master Wagering License CT, LLC
# 142     2024/25  07/31/2024 12:00:00 AM                 Mohegan Digital, LLC
#
# ...

# %%
df1=pd.read_csv("./global_holidays.csv")
df1
# Out:
#         ADM_name ISO3        Date                          Name  \
# 0          Aruba  ABW  2010-01-01                New Year's Day
# 1          Aruba  ABW  2010-01-25        Betico Croes' Birthday
# 2          Aruba  ABW  2010-02-15               Carnival Monday
# 3          Aruba  ABW  2010-03-18  National Anthem and Flag Day
# 4          Aruba  ABW  2010-04-02                   Good Friday
# ...          ...  ...         ...                           ...
# 44388  Palestine  PSE  2015-12-24            Prophet's Birthday
# 44389  Palestine  PSE  2016-12-12            Prophet's Birthday
# 44390  Palestine  PSE  2017-12-01            Prophet's Birthday
# 44391  Palestine  PSE  2018-11-21            Prophet's Birthday
# 44392  Palestine  PSE  2019-11-10            Prophet's Birthday
#
#                  Type
# 0      Public holiday
# 1      Public holiday
# 2      Public holiday
# 3      Public holiday
# 4      Public holiday
# ...               ...
# 44388  Public holiday
# ...

# %%
df2=pd.read_csv("./most-visited-countries-2024.csv")
df2
# Out:
#               country  MostVisited_NumOfArrivalsPredictive_Millions_2024  \
# 0               India                                               17.9
# 1               China                                               65.7
# 2       United States                                               79.3
# 3           Indonesia                                               15.5
# 4            Pakistan                                                NaN
# ..                ...                                                ...
# 198            Monaco                                                NaN
# 199  Marshall Islands                                                NaN
# 200        San Marino                                                NaN
# 201             Palau                                                NaN
# 202            Tuvalu                                                NaN
#
#      MostVisited_NumOfArrivals_Millions_2023  \
# ...

# %%
df3=pd.read_csv("./social_media_entertainment_data.csv")
df3
# Out:
#         User ID  Age  Gender  Country  Daily Social Media Time (hrs)  \
# 0             1   32   Other  Germany                           4.35
# 1             2   62   Other    India                           4.96
# 2             3   51  Female      USA                           6.78
# 3             4   44  Female    India                           5.06
# 4             5   21   Other  Germany                           2.57
# ...         ...  ...     ...      ...                            ...
# 299995   299996   17  Female   Canada                           1.98
# 299996   299997   45  Female  Germany                           3.78
# 299997   299998   45    Male   Canada                           6.25
# 299998   299999   15    Male      USA                           6.47
# 299999   300000   49   Other  Germany                           1.27
#
#         Daily Entertainment Time (hrs)  Social Media Platforms Used  \
# 0                                 4.08                            5
# ...

# %%
df4=pd.read_csv("./Unique_Tourist_Destinations.csv")
df4
# Out:
#            Destination Country   Famous Attraction    Best Time to Visit  \
# 0        Destination_1  France           Colosseum     July to September
# 1        Destination_2   Spain          Mount Fuji          March to May
# 2        Destination_3   Japan    Brandenburg Gate   October to December
# 3        Destination_4  Turkey  Sydney Opera House   October to December
# 4        Destination_5   China        Burj Khalifa          March to May
# ...                ...     ...                 ...                   ...
# 1995  Destination_1996  France        Eiffel Tower          March to May
# 1996  Destination_1997     UAE      Table Mountain  November to February
# 1997  Destination_1998     USA          Red Square   October to December
# 1998  Destination_1999   Spain        Hagia Sophia            Year-round
# 1999  Destination_2000   India        Grand Palace  November to February
#
#                                         Known For
# ...
