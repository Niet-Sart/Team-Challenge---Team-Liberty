# %%
import pandas as pd

# %% [markdown]
# Fuente
# https://www.kaggle.com/datasets/ayushcx/nike-global-sales-data-2024

# %%
df_bea= pd.read_csv("./data/nike_sales_2024.csv")
df_bea
# Out:
#         Month         Region Main_Category Sub_Category       Product_Line  \
# 0    November          India     Equipment         Bags           Gym Sack
# 1     January          India     Equipment  Accessories               Hats
# 2     October          India       Apparel         Tops        Tech Fleece
# 3    December  Greater China      Footwear      Cricket      Vapor Cricket
# 4         May  Greater China     Equipment        Socks  Performance Socks
# ..        ...            ...           ...          ...                ...
# 995   October          India     Equipment  Accessories               Hats
# 996      July         Europe     Equipment        Socks  Performance Socks
# 997    August          Japan      Footwear     Football     Phantom Vision
# 998       May    South Korea     Equipment        Socks         Crew Socks
# 999  December          Japan      Footwear      Cricket      Vapor Cricket
#
# ...

# %% [markdown]
# * 4 Variables numéricas y 6 categóricas
# * 1000 filas y 10 columnas
# * Podemos predecir el “Revenue_USD” en función de las características de los productos y las ventas
# * Y se pueden aplicar en las variables:
#     * tipifica_variables -> podemos normalizar los Units_Solds, Revenue_USD y Retail_Price.
#     * get_features_num_regression y plot_features_num_regression -> quizás podemos explorar la relación entre Revenue_USD vs. Units_Sold
#     * get_features_cat_regression y plot_features_cat_regression: Nos servirá para analizar la relación entre variables categóricas (Region, Main_Category) y el target (que puede ser Revenue_USD)
#     * Variable target (Revenue_USD) -> predecir los ingresos generados en función de las características del producto, las ventas y otras .
